# %% [markdown]
# # Práctica Clase 2

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %%
import os
archivo = open('Emisiones_CO2.csv', 'r')

# %%
dicc_emisiones = {  'cod_pais' : [], # 0
                    'nom_pais' : [],  #1
                    'region' : [],  #2 
                    'anio' : [], #3
                    'co2' : [], #4
                    'co2_percapita' : []}#5

# %%
next(archivo)
totalco2 = 0
for linea in archivo: 
    linea = linea.split(sep = "|")
    for a, i in enumerate(linea):
        i = i.replace("." , "")
        i = i.replace("," , ".")
        linea [a] = i
        if linea[a] == "" or linea [a] == "\n":
            linea[a] ="valor no encontrado"
    dicc_emisiones["cod_pais"].append(linea[0])
    dicc_emisiones['nom_pais'].append(linea[1])
    dicc_emisiones['region'].append(linea[2])
    dicc_emisiones['anio'].append(int(linea[3]))
    if linea [4] == "valor no encontrado":
        dicc_emisiones['co2'].append(linea[4])
    else:
        dicc_emisiones['co2'].append(float(linea[4]))
    if linea [5] == "valor no encontrado":
        dicc_emisiones['co2'].append(linea[5])
    else:
        dicc_emisiones['co2'].append(float(linea[5]))

    if linea[2]=="América Latina y Caribe" and linea[3]=="2010":
        if linea[4]=="valor no encontrado":
            continue
        else:
            totalco2 +=float(linea[4])

print(dicc_emisiones)
print(dicc_emisiones["cod_pais"])
print(dicc_emisiones["nom_pais"])
print(dicc_emisiones["region"])
print(dicc_emisiones["anio"])
print(dicc_emisiones["co2"])
print(dicc_emisiones["co2_percapita"])
print(totalco2)
columna1 = len(dicc_emisiones["cod_pais"])
columna2 =len(dicc_emisiones["nom_pais"])
columna3 =len(dicc_emisiones["region"])
columna4 =len(dicc_emisiones["anio"])
columna5 =len(dicc_emisiones["co2"])
columna6 =len(dicc_emisiones["co2_percapita"])
# Out:
# {'cod_pais': ['ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'ABW', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AND', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG', 'AFG
# ...

# %%
region = dicc_emisiones['region']
anio = dicc_emisiones['anio']
co2 = dicc_emisiones['co2']

total = []
lista_floar = []
for a,b,c in zip(region,anio,co2):
    if a == 'América Latina y Caribe' and b == '2010':
        total.append(c.replace('.','').replace(',','.'))



total = [x for x in total if x != '']

total = [float(x) for x in total]

print(total)
# Out:
# []

# %% [markdown]
# 2) a) ¿Cuántas variables hay? <br>
# b) ¿Qué tipos de datos usar para cada una? <br>
# c) ¿Qué tipo de variables son? <br>
# d) ¿Hay valores faltantes? <br>
# e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?

# %%
valor_total = columna1 + columna2 + columna3 + columna4 + columna5 + columna6
print(valor_total)
print(f"a)hay un total de {len(dicc_emisiones)} de variables, sumadas dan un total de {valor_total} ")

print(f"b)se utilizán los tipos de datos: str para todos, menos algunos de año que son int y de co2 y co2 percapita, que son floats  ")
print("c)")
print(f"el tipo de variable del 'cod_pais' es cualitativo categorico")
print(f"el tipo de variable del 'nom_país' es cualitativo categorico")
print(f"el tipo de variable del 'region' es cualitativo categorico")
print(f"el tipo de variable del 'anio' es cualitativo ordinal")
print(f"el tipo de variable del 'co2' es cuantitativo continuo")
print(f"el tipo de variable del 'co2 per capita' es cuantitativo continuo")

print(f"d)hay en las filas 4 y 5")


print(f"e) la cantidad de emisiones fue {totalco2}")
archivo.close()
# Out:
# 66762
# a)hay un total de 6 de variables, sumadas dan un total de 66762
# b)se utilizán los tipos de datos: str para todos, menos algunos de año que son int y de co2 y co2 percapita, que son floats
# c)
# el tipo de variable del 'cod_pais' es cualitativo categorico
# el tipo de variable del 'nom_país' es cualitativo categorico
# el tipo de variable del 'region' es cualitativo categorico
# el tipo de variable del 'anio' es cualitativo ordinal
# el tipo de variable del 'co2' es cuantitativo continuo
# el tipo de variable del 'co2 per capita' es cuantitativo continuo
# d)hay en las filas 4 y 5
# e) la cantidad de emisiones fue 1691634.8009999995
